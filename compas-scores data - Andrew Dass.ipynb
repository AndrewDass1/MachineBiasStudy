# %%
import pandas as pd

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)

print(Data)
# Out:
#        Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName  \
# 0          50844         57167    51950    PRETRIAL   Fisher     Kevin
# 1          50844         57167    51950    PRETRIAL   Fisher     Kevin
# 2          50844         57167    51950    PRETRIAL   Fisher     Kevin
# 3          50848         57174    51956    PRETRIAL  KENDALL     KEVIN
# 4          50848         57174    51956    PRETRIAL  KENDALL     KEVIN
# ...          ...           ...      ...         ...      ...       ...
# 60838      65667         79665    72038   Probation     West     James
# 60839      65667         79665    72038   Probation     West     James
# 60840      68603         79669    72042    PRETRIAL     Ryan   Michael
# 60841      68603         79669    72042    PRETRIAL     Ryan   Michael
# 60842      68603         79669    72042    PRETRIAL     Ryan   Michael
#
#       MiddleName Sex_Code_Text  Ethnic_Code_Text DateOfBirth  ...  \
# ...

# %%
import pandas as pd

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)

Data.head()
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ...  RecSupervisionLevel  \
# 0          Male        Caucasian    12/05/92  ...                    1
# 1          Male        Caucasian    12/05/92  ...                    1
# 2          Male        Caucasian    12/05/92  ...                    1
# 3          Male        Caucasian    09/16/84  ...                    1
# 4          Male        Caucasian    09/16/84  ...                    1
#
# ...

# %%
#import pandas as pd
#Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)
# !pip install xlrd

# %%
#https://www.marsja.se/how-to-save-a-seaborn-plot-as-a-file-e-g-png-pdf-eps-tiff/

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)
sns.distplot(Data['RawScore'])
plt.title(f"Raw Score of Every Individual")
plt.xlabel("RawScore (ranked from -10 to 60)")
plt.ylabel("Fraction of Individual Population that Received the Same Score")
plt.xticks(np.arange(-10, 61, 5))
# Out:
# ([<matplotlib.axis.XTick at 0x19973016d88>,
# ...
#  <a list of 15 Text xticklabel objects>)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#ethnicity vs rawscore (threat level)

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)
plot = sns.catplot(x="Ethnic_Code_Text", y="RawScore", data = Data)
plt.title(f"Raw Score of Different Ethnic Individuals")
plt.xticks(rotation=60)
plt.xlabel("Different Ethnicities of People in Prison")
plt.figure(figsize=(20,50))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)
plot = sns.catplot(x="Sex_Code_Text", y="RawScore", data = Data)
plt.title("Raw Score of Females Versus Males")
plt.xlabel("Gender")
# Out:
# Text(0.5, 6.79999999999999, 'Gender')

# %%
#find how many people in each category 
#find total amount of males
#find total amount of females
#use barplots
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)
sns.scatterplot(x = 'Sex_Code_Text', y = 'RawScore', data = Data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)
sns.scatterplot(x = 'Ethnic_Code_Text', y = 'DecileScore', data = Data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)
sns.scatterplot(x = 'RawScore', y = 'DecileScore', data = Data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)
plot = sns.catplot(x="Scale_ID", y="RawScore", data = Data)
plt.title("The Scale_ID's and RawScores of Every Prisoner")
# Out:
# Text(0.5, 1, "The Scale_ID's and RawScores of Every Prisoner")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)
sns.distplot(Data['DecileScore'])
plt.title(f"Decile Score of Every Individual")
plt.xlabel("Decile Score (ranked from -5 to 15)")
plt.ylabel("Fraction of Individual Population that Received the Same Score")
plt.xticks(np.arange(-5, 16, 1))
# Out:
# ([<matplotlib.axis.XTick at 0x16654528188>,
# ...
#  <a list of 21 Text xticklabel objects>)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

Data = pd.read_csv('data/compas-scores-raw.csv', skiprows = False)
plot = sns.catplot(x="DisplayText", y="RawScore", data = Data)
plt.title("RawScores Corresponding to Every Prisoner's Display Text")
plt.xticks(rotation=60)
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)
