# %%
import pandas as pd
Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)
#prining all the columns again

Data.head()

#check out what is a countplot
# Out:
#     id              name    first       last compas_screening_date   sex  \
# 0  1.0  miguel hernandez   miguel  hernandez            14/08/2013  Male
# 1  2.0  miguel hernandez   miguel  hernandez            14/08/2013  Male
# 2  3.0      michael ryan  michael       ryan            31/12/2014  Male
# 3  4.0       kevon dixon    kevon      dixon            27/01/2013  Male
# 4  5.0          ed philo       ed      philo            14/04/2013  Male
#
#           dob  age          age_cat              race  ...  \
# 0  18/04/1947   69  Greater than 45             Other  ...
# 1  18/04/1947   69  Greater than 45             Other  ...
# 2  06/02/1985   31          25 - 45         Caucasian  ...
# 3  22/01/1982   34          25 - 45  African-American  ...
# 4  14/05/1991   24     Less than 25  African-American  ...
#
#    v_type_of_assessment  v_decile_score  v_score_text  v_screening_date  \
# 0      Risk of Violence               1           Low        14/08/2013
# ...

# %%
#decile score
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)

plt.xlabel('V_Decile Scores (ranked from 0 to 10)')
Data['v_decile_score'].plot(kind='hist')

plt.ylabel('Number of V_Decile Scores')
plt.title('V_Decile Scores of Prisoners')
plt.xlim([0, 10])
plt.xticks(np.arange(-1, 12, 1))
# Out:
# ([<matplotlib.axis.XTick at 0x1ec9d336208>,
# ...
#  <a list of 13 Text xticklabel objects>)

# %%
import pandas as pd
import seaborn as sns
Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)

sns.scatterplot(x = 'Age', y = 'V_decile_score', data = Data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-3b2e4459fcf1> in <module>
#       3 Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)
#       4
# ----> 5 sns.scatterplot(x = 'Age', y = 'V_decile_score', data = Data)
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1400         x_bins=x_bins, y_bins=y_bins,
#    1401         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1402         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1403     )
#    1404
#
# ...

# %%
import pandas as pd
import numpy as np

Data2 = 'data/cox-violent-parsed.csv'
cols = [11,14]

Data3 = pd.read_csv(Data2,index_col=0, usecols=cols)
Data3.head()
# Out:
#               priors_count
# decile_score
# 1                        0
# 1                        0
# 5                        0
# 3                        0
# 4                        4

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)
plot = sns.catplot(x="v_score_text", y="v_decile_score", data = Data)

plt.title("Violent Scores Associated with Violent Decile Scores")
plt.xlabel("Danger Level of a Person's Violent Score")
plt.ylabel("Decile Risk Score Level Assigned to Corresponding Violent Score (from 1 to 10)")
# Out:
# Text(10.049999999999997, 0.5, 'Decile Risk Score Level Assigned to Corresponding Violent Score (from 1 to 10)')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)
plot = sns.catplot(x="race", y="age", data = Data)

plt.title(f"Ages of Different Ethnic Prisoners")
plt.xticks(rotation=60)
plt.xlabel("Different Ethnicities of People in Prison")
plt.ylabel("Age")
plt.figure(figsize=(20,50))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)
plot = sns.catplot(x="age", y="c_charge_desc", data = Data)

plt.title(f"Ages of Different Ethnic Prisoners")
plt.xticks(rotation='vertical')
plt.xlabel("Different Ethnicities of People in Prison")
plt.ylabel("Age")

plt.figure(figsize=(20,50))
#plt.xticks(np.arange(0, 50, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x1a746cd9b48>,
# ...
#  <a list of 50 Text xticklabel objects>)

# %%
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)


fig = px.bar(x=["decile_score"], y =["age"])
fig.show()
fig.update_xaxes(type='category')

#doesn't work

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)

sns.swarmplot(x="decile_score", y="v_decile_score", data=Data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)
plot = sns.catplot(x="sex", y="id", data = Data)

plt.title("The Number of Women and Men in Prison")
plt.xticks(rotation=60)
plt.xlabel("Gender")
plt.ylabel("id")
plt.figure(figsize=(20,50))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)
plot = sns.catplot(x="race", y="id", data = Data)

plt.title(f"The Total Amount of each Different Ethnic Populations in Prison")
plt.xticks(rotation=60)
plt.xlabel("Different Ethnicities of People in Prison")
plt.ylabel("id")
plt.figure(figsize=(20,50))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


Data = pd.read_csv('data/cox-violent-parsed.csv', skiprows = False)
plot = sns.catplot(x="race", y="v_decile_score", data = Data)

plt.title(f"The Total Amount of each Different Ethnic Populations in Prison")
plt.xticks(rotation=60)
plt.xlabel("Different Ethnicities of People in Prison")
plt.ylabel("id")
plt.figure(figsize=(20,50))
